# %% [markdown]
# # 1. Merging dataframes

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import pandas_profiling

# %%
ggg = pd.read_csv('/Users/claudia/Ironhack/Final Project/Dataset/Global_Gender_Gap_index.csv')

# %%
ggg.head()
# Out:
#    Global_rank    country  Global_score Global_Delta_Rank_2018  \
# 0           20    Albania         0.769                     14
# 1          132    Algeria         0.634                     -4
# 2          118     Angola         0.660                      7
# 3           30  Argentina         0.746                      6
# 4           98    Armenia         0.684                      Ð
#
#   Global_2018_Score_change  Global_2006_Score_change
# 0                    0.035                     0.108
# 1                    0.005                     0.032
# 2                    0.027                     0.056
# 3                    0.014                     0.063
# 4                    0.006                       NaN

# %%
e_o = pd.read_csv('/Users/claudia/Ironhack/Final Project/Dataset/Economic_Partecipation and Opportunity.csv')

# %%
p_e = pd.read_csv('/Users/claudia/Ironhack/Final Project/Dataset/Political_Empowerment.csv')

# %%
ed = pd.read_csv('/Users/claudia/Ironhack/Final Project/Dataset/Educational Attainment.csv')

# %%
h_s = pd.read_csv('/Users/claudia/Ironhack/Final Project/Dataset/Health and Survival.csv')

# %%
ggg_years = pd.read_excel('/Users/claudia/Ironhack/Final Project/Dataset/gender_gap_report_years.xlsx')

# %%
ggg_years
# Out:
#        country          Region    2006    2007    2008    2009    2010  \
# 0      Albania          Europe  0.6607  0.6685  0.6591  0.6601  0.6726
# 1      Algeria          Africa  0.6018  0.6068  0.6111  0.6119  0.6052
# 2       Angola          Africa  0.6039  0.6034  0.6032  0.6353  0.6712
# 3    Argentina   South America  0.6829  0.6982  0.7209  0.7211  0.7187
# 4      Armenia       West Asia     NaN  0.6651  0.6677  0.6619  0.6669
# ..         ...             ...     ...     ...     ...     ...     ...
# 142  Venezuela   South America  0.6664  0.6797  0.6875  0.6839  0.6863
# 143    Vietnam  Southeast Asia     NaN  0.6889  0.6778  0.6802  0.6776
# 144      Yemen       West Asia  0.4595  0.4510  0.4664  0.4609  0.4603
# 145     Zambia          Africa  0.6360  0.6288  0.6205  0.6310  0.6293
# 146   Zimbabwe          Africa  0.6461  0.6464  0.6485  0.6518  0.6574
#
#        2011    2012    2013    2014   2015   2016   2017   2018   2020
# ...

# %%
h_s.shape
# Out:
# (153, 3)

# %%
ed.shape
# Out:
# (153, 3)

# %%
p_e.shape
# Out:
# (153, 3)

# %%
e_o.shape
# Out:
# (153, 3)

# %%
ggg1 = ggg.merge(p_e, on='country', how='left')

# %%
ggg1.shape
# Out:
# (153, 8)

# %%
ggg2 = ggg1.merge(e_o, on='country', how='left')

# %%
ggg2.shape
# Out:
# (153, 10)

# %%
ggg2.head()
# Out:
#    Global_rank    country  Global_score Global_Delta_Rank_2018  \
# 0           20    Albania         0.769                     14
# 1          132    Algeria         0.634                     -4
# 2          118     Angola         0.660                      7
# 3           30  Argentina         0.746                      6
# 4           98    Armenia         0.684                      Ð
#
#   Global_2018_Score_change  Global_2006_Score_change  P_rank  P_score  \
# 0                    0.035                     0.108    23.0    0.376
# 1                    0.005                     0.032    99.0    0.145
# 2                    0.027                     0.056    46.0    0.262
# 3                    0.014                     0.063    22.0    0.387
# 4                    0.006                       NaN   114.0    0.118
#
#    E_O_rank  E_O_score
# 0      36.0      0.743
# 1     138.0      0.461
# 2      96.0      0.640
# 3     103.0      0.623
# 4      78.0      0.673

# %%
ggg3 = ggg2.merge(ed, on='country', how='left')

# %%
ggg3.head()
# Out:
#    Global_rank    country  Global_score Global_Delta_Rank_2018  \
# 0           20    Albania         0.769                     14
# 1          132    Algeria         0.634                     -4
# 2          118     Angola         0.660                      7
# 3           30  Argentina         0.746                      6
# 4           98    Armenia         0.684                      Ð
#
#   Global_2018_Score_change  Global_2006_Score_change  P_rank  P_score  \
# 0                    0.035                     0.108    23.0    0.376
# 1                    0.005                     0.032    99.0    0.145
# 2                    0.027                     0.056    46.0    0.262
# 3                    0.014                     0.063    22.0    0.387
# 4                    0.006                       NaN   114.0    0.118
#
#    E_O_rank  E_O_score  E_rank  E_score
# 0      36.0      0.743    40.0    0.999
# 1     138.0      0.461   109.0    0.966
# 2      96.0      0.640   147.0    0.759
# ...

# %%
ggg4 = ggg3.merge(h_s, on='country', how='left')

# %%
ggg4.shape
# Out:
# (153, 14)

# %%
ggg_2020 = ggg4.merge(ggg_years, on='country', how='left')

# %%
ggg_2020.shape
# Out:
# (153, 29)

# %%
ggg_2020.head()
# Out:
#    Global_rank    country  Global_score Global_Delta_Rank_2018  \
# 0           20    Albania         0.769                     14
# 1          132    Algeria         0.634                     -4
# 2          118     Angola         0.660                      7
# 3           30  Argentina         0.746                      6
# 4           98    Armenia         0.684                      Ð
#
#   Global_2018_Score_change  Global_2006_Score_change  P_rank  P_score  \
# 0                    0.035                     0.108    23.0    0.376
# 1                    0.005                     0.032    99.0    0.145
# 2                    0.027                     0.056    46.0    0.262
# 3                    0.014                     0.063    22.0    0.387
# 4                    0.006                       NaN   114.0    0.118
#
#    E_O_rank  E_O_score  ...    2010    2011    2012    2013    2014   2015  \
# 0      36.0      0.743  ...  0.6726  0.6748  0.6655  0.6412  0.6869  0.701
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
ggg_2020.head()
# Out:
#    Global_rank    country  Global_score Global_Delta_Rank_2018  \
# 0           20    Albania         0.769                     14
# 1          132    Algeria         0.634                     -4
# 2          118     Angola         0.660                      7
# 3           30  Argentina         0.746                      6
# 4           98    Armenia         0.684                      Ð
#
#   Global_2018_Score_change  Global_2006_Score_change  P_rank  P_score  \
# 0                    0.035                     0.108    23.0    0.376
# 1                    0.005                     0.032    99.0    0.145
# 2                    0.027                     0.056    46.0    0.262
# 3                    0.014                     0.063    22.0    0.387
# 4                    0.006                       NaN   114.0    0.118
#
#    E_O_rank  E_O_score  E_rank  E_score  H_S_rank  H_S_score         Region  \
# 0      36.0      0.743    40.0    0.999     145.0      0.958         Europe
# ...

# %%
ggg_2020.shape
# Out:
# (153, 29)

# %%
ggg_2020.drop(ggg_2020.iloc[:, 15:28], inplace=True, axis=1)

# %%
ggg_2020.head()
# Out:
#    Global_rank    country  Global_score Global_Delta_Rank_2018  \
# 0           20    Albania         0.769                     14
# 1          132    Algeria         0.634                     -4
# 2          118     Angola         0.660                      7
# 3           30  Argentina         0.746                      6
# 4           98    Armenia         0.684                      Ð
#
#   Global_2018_Score_change  Global_2006_Score_change  P_rank  P_score  \
# 0                    0.035                     0.108    23.0    0.376
# 1                    0.005                     0.032    99.0    0.145
# 2                    0.027                     0.056    46.0    0.262
# 3                    0.014                     0.063    22.0    0.387
# 4                    0.006                       NaN   114.0    0.118
#
#    E_O_rank  E_O_score  E_rank  E_score  H_S_rank  H_S_score         Region  \
# 0      36.0      0.743    40.0    0.999     145.0      0.958         Europe
# ...

# %%
ggg_2020= ggg_2020.drop(ggg_2020.columns[-1],axis=1)

# %%
ggg_2020
# Out:
#      Global_rank    country  Global_score Global_Delta_Rank_2018  \
# 0             20    Albania         0.769                     14
# 1            132    Algeria         0.634                     -4
# 2            118     Angola         0.660                      7
# 3             30  Argentina         0.746                      6
# 4             98    Armenia         0.684                      Ð
# ..           ...        ...           ...                    ...
# 148           67  Venezuela         0.713                     -3
# 149           87    Vietnam         0.700                    -10
# 150          153      Yemen         0.494                     -4
# 151           45     Zambia         0.731                    NaN
# 152           47   Zimbabwe         0.730                      Ð
#
#     Global_2018_Score_change  Global_2006_Score_change  P_rank  P_score  \
# 0                      0.035                     0.108    23.0    0.376
# ...

# %%
pop = pd.read_csv('/Users/claudia/Ironhack/Final Project/Dataset/population_total.csv')

# %%
pop.shape
# Out:
# (195, 302)

# %%
pop.head()
# Out:
#        country     1800     1801     1802     1803     1804     1805     1806  \
# 0  Afghanistan  3280000  3280000  3280000  3280000  3280000  3280000  3280000
# 1      Albania   400000   402000   404000   405000   407000   409000   411000
# 2      Algeria  2500000  2510000  2520000  2530000  2540000  2550000  2560000
# 3      Andorra     2650     2650     2650     2650     2650     2650     2650
# 4       Angola  1570000  1570000  1570000  1570000  1570000  1570000  1570000
#
#       1807     1808     1809     1810     1811     1812     1813     1814  \
# 0  3280000  3280000  3280000  3280000  3280000  3280000  3280000  3280000
# 1   413000   414000   416000   418000   420000   422000   424000   426000
# 2  2560000  2570000  2580000  2590000  2600000  2610000  2620000  2630000
# 3     2650     2650     2650     2650     2650     2650     2650     2650
# 4  1570000  1570000  1570000  1570000  1570000  1570000  1570000  1570000
#
# ...

# %%
pop_20 = pop.loc[:, ['country', '2020']]

# %%
ggg_2020 = ggg_2020.merge(pop_20, on='country', how='left')

# %%
ggg_20 = ggg_2020.rename(columns={"2020": "pop_2020"})

# %%
ggg_20
# Out:
#      Global_rank    country  Global_score Global_Delta_Rank_2018  \
# 0             20    Albania         0.769                     14
# 1            132    Algeria         0.634                     -4
# 2            118     Angola         0.660                      7
# 3             30  Argentina         0.746                      6
# 4             98    Armenia         0.684                      Ð
# ..           ...        ...           ...                    ...
# 148           67  Venezuela         0.713                     -3
# 149           87    Vietnam         0.700                    -10
# 150          153      Yemen         0.494                     -4
# 151           45     Zambia         0.731                    NaN
# 152           47   Zimbabwe         0.730                      Ð
#
#     Global_2018_Score_change  Global_2006_Score_change  P_rank  P_score  \
# 0                      0.035                     0.108    23.0    0.376
# ...

# %%
wages = pd.read_csv('/Users/claudia/Ironhack/Final Project/Dataset/Wage and salaried workers_% of female employment.csv')

# %%
wages.head()
# Out:
#        country   1991   1992   1993   1994   1995   1996   1997   1998  1999  \
# 0  Afghanistan   1.45   1.56   1.44   1.53   2.06   1.57   1.57   1.59   1.6
# 1      Albania  27.70  27.60  27.70  28.60  29.50  30.30  31.80  31.80  32.5
# 2      Algeria  60.80  60.90  61.10  61.10  61.10  61.10  61.30  61.30  61.4
# 3       Angola  18.90  19.10  19.40  19.70  20.00  20.20  20.60  20.90  21.2
# 4    Argentina  71.40  72.50  71.30  72.10  74.90  74.30  75.00  75.50  75.8
#
#     2000   2001   2002   2003   2004   2005  2006   2007  2008   2009  2010  \
# 0   1.61   1.64   2.19   1.67   1.63   1.74   1.7   1.76   1.7   2.11   2.3
# 1  33.70  34.70  36.00  37.10  38.30  39.50  40.7  41.90  32.8  34.80  37.0
# 2  61.50  61.60  63.90  66.10  67.50  68.60  69.8  70.80  71.8  72.70  73.6
# 3  21.50  21.70  21.90  22.30  22.50  21.60  20.7  19.80  19.0  18.20  17.1
# 4  76.40  76.10  78.10  78.80  79.00  79.40  80.2  80.90  80.8  80.10  80.6
#
# ...

# %%
wages_20 = wages.loc[:, ['country', '2020']]

# %%
wages_20.head()
# Out:
#        country   2020
# 0  Afghanistan   8.03
# 1      Albania  47.10
# 2      Algeria  74.70
# 3       Angola  17.90
# 4    Argentina  77.20

# %%
ggg_20 = ggg_20.merge(wages_20, on='country', how='left')

# %%
ggg_20
# Out:
#      Global_rank    country  Global_score Global_Delta_Rank_2018  \
# 0             20    Albania         0.769                     14
# 1            132    Algeria         0.634                     -4
# 2            118     Angola         0.660                      7
# 3             30  Argentina         0.746                      6
# 4             98    Armenia         0.684                      Ð
# ..           ...        ...           ...                    ...
# 148           67  Venezuela         0.713                     -3
# 149           87    Vietnam         0.700                    -10
# 150          153      Yemen         0.494                     -4
# 151           45     Zambia         0.731                    NaN
# 152           47   Zimbabwe         0.730                      Ð
#
#     Global_2018_Score_change  Global_2006_Score_change  P_rank  P_score  \
# 0                      0.035                     0.108    23.0    0.376
# ...

# %%
ggg_20 =ggg_20.rename(columns={"2020": "wages_2020"})

# %%
ggg_20
# Out:
#      Global_rank    country  Global_score Global_Delta_Rank_2018  \
# 0             20    Albania         0.769                     14
# 1            132    Algeria         0.634                     -4
# 2            118     Angola         0.660                      7
# 3             30  Argentina         0.746                      6
# 4             98    Armenia         0.684                      Ð
# ..           ...        ...           ...                    ...
# 148           67  Venezuela         0.713                     -3
# 149           87    Vietnam         0.700                    -10
# 150          153      Yemen         0.494                     -4
# 151           45     Zambia         0.731                    NaN
# 152           47   Zimbabwe         0.730                      Ð
#
#     Global_2018_Score_change  Global_2006_Score_change  P_rank  P_score  \
# 0                      0.035                     0.108    23.0    0.376
# ...

# %%
ggg_20 = pd.read_csv('/Users/claudia/Ironhack/Final Project/Dataset/ggg_20.csv')

# %%
ggg_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Global_rank               153 non-null    int64
#  1   country                   153 non-null    object
#  2   Region                    153 non-null    object
#  3   regional_indicator        153 non-null    object
#  4   Global_score              153 non-null    float64
#  5   Global_Delta_Rank_2018    149 non-null    object
#  6   Global_2018_Score_change  149 non-null    object
#  7   Global_2006_Score_change  115 non-null    float64
#  8   P_rank                    153 non-null    int64
#  9   P_score                   153 non-null    float64
#  10  E_O_rank                  153 non-null    int64
#  11  E_O_score                 153 non-null    float64
#  12  E_rank                    153 non-null    int64
# ...

# %%
parl_seat = pd.read_csv('/Users/claudia/Ironhack/Final Project/Dataset/Proportion of seats held by women in national parliaments %.csv')

# %%
parl_seat.head()
# Out:
#           country code      1997      1998      1999      2000       2001  \
# 0     Afghanistan  AFG       NaN       NaN       NaN       NaN        NaN
# 1         Albania  ALB       NaN       NaN  5.161290  5.161290   5.714286
# 2         Algeria  DZA  3.157895  3.157895  3.157895  3.421053   3.421053
# 3  American Samoa  ASM       NaN       NaN       NaN       NaN        NaN
# 4         Andorra  AND  7.142857  7.142857  7.142857  7.142857  14.285714
#
#         2002       2003       2004       2005       2006       2007  \
# 0        NaN        NaN        NaN  27.309237  27.309237  27.685950
# 1   5.714286   5.714286   6.428571   7.142857   7.142857   7.142857
# 2   6.169666   6.169666   6.169666   6.169666   6.169666   7.712082
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4  14.285714  14.285714  14.285714  28.571429  28.571429  28.571429
#
#         2008       2009       2010       2011       2012       2013  \
# ...

# %%
parl_seat_20 = parl_seat.loc[:, ['country', 'code', '2020']]

# %%
ggg_20 = ggg_20.merge(parl_seat_20, on='country', how='left')

# %%
ggg_20 =ggg_20.rename(columns={"2020": "parl_seat_20"})

# %%
ggg_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 153 entries, 0 to 152
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Global_rank               153 non-null    int64
#  1   country                   153 non-null    object
#  2   Region                    153 non-null    object
#  3   regional_indicator        153 non-null    object
#  4   Global_score              153 non-null    float64
#  5   Global_Delta_Rank_2018    149 non-null    object
#  6   Global_2018_Score_change  149 non-null    object
#  7   Global_2006_Score_change  115 non-null    float64
#  8   P_rank                    153 non-null    int64
#  9   P_score                   153 non-null    float64
#  10  E_O_rank                  153 non-null    int64
#  11  E_O_score                 153 non-null    float64
#  12  E_rank                    153 non-null    int64
# ...

# %%
labour_force = pd.read_csv('/Users/claudia/Ironhack/Final Project/Dataset/females_labour_force_aged_15_64_percent.csv')

# %%
ggg_20 =ggg_20.rename(columns={"2020": "labour_force_20"})

# %%
ggg_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 153 entries, 0 to 152
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Global_rank               153 non-null    int64
#  1   country                   153 non-null    object
#  2   Region                    153 non-null    object
#  3   regional_indicator        153 non-null    object
#  4   Global_score              153 non-null    float64
#  5   Global_Delta_Rank_2018    149 non-null    object
#  6   Global_2018_Score_change  149 non-null    object
#  7   Global_2006_Score_change  115 non-null    float64
#  8   P_rank                    153 non-null    int64
#  9   P_score                   153 non-null    float64
#  10  E_O_rank                  153 non-null    int64
#  11  E_O_score                 153 non-null    float64
#  12  E_rank                    153 non-null    int64
# ...

# %%
unpaid_domestic = pd.read_csv('/Users/claudia/Ironhack/Final Project/Dataset/unpaid_domestic_work_fe.csv')

# %%
unpaid_domestic_avg = unpaid_domestic.loc[:, ['country', 'Avg_hr']]

# %%
ggg_20 = ggg_20.merge(unpaid_domestic_avg, on='country', how='left')

# %%
ggg_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 153 entries, 0 to 152
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Global_rank               153 non-null    int64
#  1   country                   153 non-null    object
#  2   Region                    153 non-null    object
#  3   regional_indicator        153 non-null    object
#  4   Global_score              153 non-null    float64
#  5   Global_Delta_Rank_2018    149 non-null    object
#  6   Global_2018_Score_change  149 non-null    object
#  7   Global_2006_Score_change  115 non-null    float64
#  8   P_rank                    153 non-null    int64
#  9   P_score                   153 non-null    float64
#  10  E_O_rank                  153 non-null    int64
#  11  E_O_score                 153 non-null    float64
#  12  E_rank                    153 non-null    int64
# ...

# %%
ggg_20.to_csv(r'/Users/claudia/Ironhack/Final Project/Dataset/ggg_20.csv', index=False)

# %%
ggg_20 = pd.read_csv('/Users/claudia/Ironhack/Final Project/Dataset/ggg_20.csv')

# %%
ggg_20 = ggg_20.drop(['labour_force_20'], axis =1)

# %%
ggg_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Global_rank               153 non-null    int64
#  1   country                   153 non-null    object
#  2   code                      144 non-null    object
#  3   Region                    153 non-null    object
#  4   regional_indicator        153 non-null    object
#  5   Global_score              153 non-null    float64
#  6   Global_Delta_Rank_2018    149 non-null    object
#  7   Global_2018_Score_change  149 non-null    object
#  8   Global_2006_Score_change  115 non-null    float64
#  9   P_rank                    153 non-null    int64
#  10  P_score                   153 non-null    float64
#  11  E_O_rank                  153 non-null    int64
#  12  E_O_score                 153 non-null    float64
# ...

# %%
fe_labour_force_20 = labour_force.loc[:, ['country', '2020']]

# %%
fe_labour_force_20
# Out:
#          country    2020
# 0    Afghanistan  0.2040
# 1        Albania  0.5610
# 2        Algeria  0.1700
# 3         Angola  0.7630
# 4      Argentina  0.5530
# ..           ...     ...
# 174    Venezuela  0.5500
# 175      Vietnam  0.7960
# 176        Yemen  0.0572
# 177       Zambia  0.7120
# 178     Zimbabwe  0.8040
#
# [179 rows x 2 columns]

# %%
ggg_20 = ggg_20.merge(fe_labour_force_20, on='country', how='left')

# %%
ggg_20 =ggg_20.rename(columns={"2020": "labour_force_20"})

# %%
ggg_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 153 entries, 0 to 152
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Global_rank               153 non-null    int64
#  1   country                   153 non-null    object
#  2   code                      144 non-null    object
#  3   Region                    153 non-null    object
#  4   regional_indicator        153 non-null    object
#  5   Global_score              153 non-null    float64
#  6   Global_Delta_Rank_2018    149 non-null    object
#  7   Global_2018_Score_change  149 non-null    object
#  8   Global_2006_Score_change  115 non-null    float64
#  9   P_rank                    153 non-null    int64
#  10  P_score                   153 non-null    float64
#  11  E_O_rank                  153 non-null    int64
#  12  E_O_score                 153 non-null    float64
# ...

# %%
whr_20 = pd.read_excel('/Users/claudia/Ironhack/Final Project/Dataset/WHR20_reduced.xls')

# %%
whr_20
# Out:
#          Country                          sub_region  Hippiness_score  \
# 0    Afghanistan                          South Asia           2.5669
# 1        Albania          Central and Eastern Europe           4.8827
# 2        Algeria        Middle East and North Africa           5.0051
# 3      Argentina         Latin America and Caribbean           5.9747
# 4        Armenia  Commonwealth of Independent States           4.6768
# ..           ...                                 ...              ...
# 148    Venezuela         Latin America and Caribbean           5.0532
# 149      Vietnam                      Southeast Asia           5.3535
# 150        Yemen        Middle East and North Africa           3.5274
# 151       Zambia                  Sub-Saharan Africa           3.7594
# 152     Zimbabwe                  Sub-Saharan Africa           3.2992
#
#      sigma_happiness  upperwhisker  lowerwhisker  Log_GDP_per_capita  \
# ...

# %%
whr_20.columns = [x.lower() for x in whr_20.columns]

# %%
ggg_20 = ggg_20.merge(whr_20, on='country', how='left')

# %%
ggg_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 153 entries, 0 to 152
# Data columns (total 34 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Global_rank                   153 non-null    int64
#  1   country                       153 non-null    object
#  2   code                          144 non-null    object
#  3   Region                        153 non-null    object
#  4   regional_indicator            153 non-null    object
#  5   Global_score                  153 non-null    float64
#  6   Global_Delta_Rank_2018        149 non-null    object
#  7   Global_2018_Score_change      149 non-null    object
#  8   Global_2006_Score_change      115 non-null    float64
#  9   P_rank                        153 non-null    int64
#  10  P_score                       153 non-null    float64
#  11  E_O_rank                      153 non-null    int64
# ...

# %%
ggg_20.to_csv(r'/Users/claudia/Ironhack/Final Project/Dataset/ggg_20.csv', index=False)
